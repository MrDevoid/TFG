# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.model_selection  import cross_val_score
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
datosPacientes = pd.read_csv('depresjon-dataset/data/scores.csv', na_values='--undefined--')
datosPacientes = datosPacientes.drop(columns=['number'])
datosPacientes = datosPacientes.drop(columns=['days'])
actividadPaciente = []
for i in range(0, 22):
    path = 'depresjon-dataset/data/condition/condition_' + str(i+1) + '.csv'
    actividadPaciente.append(pd.read_csv(path, na_values='--undefined--'))

# %%
datosPacientes
# Out:
#     gender    age  afftype  inpatient    edu  marriage  work  madrs1  madrs2
# 0        2  35-39        2          2   6-10         1     2      19      19
# 1        2  40-44        1          2   6-10         2     2      24      11
# 2        1  45-49        2          2   6-10         2     2      24      25
# 3        2  25-29        2          2  11-15         1     1      20      16
# 4        2  50-54        2          2  11-15         2     2      26      26
# 5        1  35-39        2          2   6-10         1     2      18      15
# 6        1  20-24        1          2  11-15         2     1      24      25
# 7        2  25-29        2          2  11-15         1     2      20      16
# 8        2  45-49        1          2   6-10         1     2      26      26
# 9        2  45-49        2          2   6-10         1     2      28      21
# 10       1  45-49        2          2   6-10         1     2      24      24
# 11       2  40-44        1          2   6-10         2     2      25      21
# 12       2  35-39        1          2  11-15         2     2      18      13
# 13       1  60-64        1          2   6-10         2     2      28      19
# 14       2  55-59        2          2  11-15         1     1      14      18
# 15       1  45-49        2          2  11-15         1     2      13      17
# 16       1  50-54        1          2   6-10         1     2      17      15
# 17       2  50-54        2          1  16-20         2     2      26      21
# 18       1  30-34        2          1   6-10         1     2      27      25
# 19       2  35-39        2          1   6-10         2     2      26      21
# 20       1  65-69        2          1   6-10         2     2      29      28
# 21       1  30-34        2          1  16-20         2     2      29      23

# %%
X_activity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cff2cee6a006> in <module>()
# ----> 1 X_activity
#
# NameError: name 'X_activity' is not defined

# %%
for i in range(0, 22):
    actividadPaciente[i] = actividadPaciente[i].drop(columns=['date'])

# %%
for i in range(0, 22):
    actividadPaciente[i].index = pd.DatetimeIndex(actividadPaciente[i].timestamp)
    aux = actividadPaciente.copy()
    actividadPaciente[i] = round(aux[i].resample('2H').mean(),2)
    #actividadPaciente[i]['sumActivity'] = round(aux[i].resample('2H').sum(),2)
    actividadPaciente[i]['stdActivity'] = round(aux[i].resample('2H').std(),2)
    actividadPaciente[i]=actividadPaciente[i].rename(columns = {'activity':'meanActivity'})

#actividadPaciente.resample('1H').sum()

# %%
for i in range(0, 22):
    actividadPaciente[i]['hour'] = actividadPaciente[i].index
    actividadPaciente[i].hour = actividadPaciente[i].hour.astype(str).tolist()
    actividadPaciente[i] = actividadPaciente[i].reset_index(drop=True)

# %%
for i in range(0, 22):
    times = []
    for time in actividadPaciente[i].hour:
        times.append(time.split(' ')[1])
    actividadPaciente[i].hour = times

# %%
for j in range(0,22):
    print(j, sum(actividadPaciente[j].meanActivity[math.trunc(len(actividadPaciente[j])*0.90):]))
    while(sum(actividadPaciente[j].meanActivity[math.trunc(len(actividadPaciente[j])*0.90):]) < sum(actividadPaciente[j].meanActivity[:math.trunc((len(actividadPaciente[j])*0.10)/3)])):
        actividadPaciente[j] = actividadPaciente[j][:math.trunc(len(actividadPaciente[j])*0.95)]
        print(j, sum(actividadPaciente[j].meanActivity[math.trunc(len(actividadPaciente[j])*0.90):]))
# Out:
# 0 885.6399999999999
# 0 3166.7099999999996
# 1 842.5699999999998
# 1 274.7299999999999
# 1 272.13
# 1 240.66000000000003
# 1 216.40999999999997
# 1 2433.289999999999
# 2 4578.140000000001
# 3 705.38
# 3 6498.039999999999
# 4 1365.75
# 5 1762.85
# 5 4251.589999999999
# 6 822.9599999999999
# 6 694.32
# 6 482.24999999999994
# 6 874.57
# 6 4342.179999999999
# 7 1168.6299999999999
# 7 298.67
# 7 85.32000000000002
# 7 1197.5999999999997
# 7 1730.0299999999997
# 8 2804.1600000000003
# 9 1630.7099999999998
# 9 4532.87
# 10 1234.1499999999999
# 11 197.02999999999997
# 11 630.8699999999999
# 11 851.9599999999999
# 11 1805.36
# 11 2924.81
# 12 79.07999999999998
# 12 4.670000000000001
# 12 1596.2699999999998
# 12 4581.7699999999995
# 13 823.5000000000002
# 13 1341.7
# 14 781.12
# 14 2398.37
# 15 1672.0300000000002
# 15 1210.51
# 15 11.01
# 15 6.739999999999999
# 15 2.7899999999999996
# 15 0.47000000000000003
# 15 0.02
# 15 0.04
# 15 0.81
# 15 1458.9899999999998
# 15 3045.3400000000006
# 16 1290.0200000000002
# 17 1254.33
# 18 27.450000000000003
# 18 0.0
# 18 0.0
# 18 418.94
# 18 935.5
# 19 2119.4000000000005
# 20 2046.4099999999999
# 21 86.18
# 21 12.7
# 21 17.930000000000003
# 21 1792.57
# 21 4673.8

# %%
actividadPaciente[0]
# Out:
#      meanActivity  sumActivity  stdActivity      hour
# 0          315.56        37867       248.04  12:00:00
# 1          248.98        29878       286.04  14:00:00
# 2          224.20        26904       234.03  16:00:00
# 3           94.79        11375       141.28  18:00:00
# 4           70.74         8489        91.88  20:00:00
# 5           90.59        10871       262.96  22:00:00
# 6            6.04          725        33.11  00:00:00
# 7            5.55          666        29.33  02:00:00
# 8            6.59          791        22.09  04:00:00
# 9           11.85         1422        31.80  06:00:00
# 10         129.09        15491       205.79  08:00:00
# 11         373.80        44856       262.37  10:00:00
# 12         297.68        35722       252.91  12:00:00
# 13         177.90        21348       254.35  14:00:00
# 14         381.40        45768       245.67  16:00:00
# 15         285.68        34282       202.90  18:00:00
# 16         142.18        17062       208.23  20:00:00
# 17          57.19         6863       100.38  22:00:00
# 18          45.98         5517       111.80  00:00:00
# 19           6.55          786        33.07  02:00:00
# 20           8.58         1030        35.76  04:00:00
# 21           6.05          726        22.97  06:00:00
# 22          99.18        11902       206.98  08:00:00
# 23         330.66        39679       326.91  10:00:00
# 24         115.38        13845       251.73  12:00:00
# 25          84.21        10105       160.44  14:00:00
# 26         229.01        27481       190.94  16:00:00
# 27         260.97        31316       178.54  18:00:00
# 28         255.62        30674       255.83  20:00:00
# 29          47.45         5694        72.86  22:00:00
# ..            ...          ...          ...       ...
# 154          7.54          905        54.74  08:00:00
# 155        252.67        30320       229.13  10:00:00
# 156        191.71        23005       219.80  12:00:00
# 157        174.64        20957       220.13  14:00:00
# 158        302.53        36304       264.88  16:00:00
# 159        223.13        26776       283.16  18:00:00
# 160        130.03        15604       184.35  20:00:00
# 161         55.53         6664        89.55  22:00:00
# 162         46.70         5604       220.86  00:00:00
# 163          8.09          971        30.01  02:00:00
# 164         11.90         1428        37.42  04:00:00
# 165          8.80         1056        42.26  06:00:00
# 166        102.24        12269       214.82  08:00:00
# 167        147.79        17735       207.42  10:00:00
# 168       1532.36       183883      1168.71  12:00:00
# 169        148.39        17807       362.31  14:00:00
# 170        157.02        18842       192.15  16:00:00
# 171         85.94        10313       204.00  18:00:00
# 172         90.29        10835       150.52  20:00:00
# 173         55.64         6677       164.12  22:00:00
# 174         28.64         3437        87.20  00:00:00
# 175          8.87         1064        41.99  02:00:00
# 176         13.16         1579        39.58  04:00:00
# 177         15.61         1873        58.30  06:00:00
# 178         38.46         4615       128.70  08:00:00
# 179        270.08        32409       334.57  10:00:00
# 180        457.50        54900       468.30  12:00:00
# 181          5.88          706        41.99  14:00:00
# 182          0.00            0         0.00  16:00:00
# 183          0.04            5         0.46  18:00:00
#
# [184 rows x 4 columns]

# %%
for i in range(0, 22):
    actividadPaciente[i].plot()
# Out:
# /home/ismael/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
finalDF = pd.DataFrame()
for i in range(0, 22):
    df1 = actividadPaciente[i]
    df2 = datosPacientes[i:i+1].reindex(datosPacientes[i:i+1].index.repeat(len(actividadPaciente[i]))).reset_index(drop=True)
    auxDF = pd.concat([df1,df2], axis=1)
    finalDF = pd.concat([finalDF,auxDF]).reset_index(drop=True)

# %%
le = preprocessing.LabelEncoder()
finalDF.age = le.fit_transform(finalDF.age)
finalDF.edu = le.fit_transform(finalDF.edu)
finalDF.hour = le.fit_transform(finalDF.hour)
finalDF = finalDF[~finalDF['stdActivity'].isnull()]
X_activity = finalDF.drop(['afftype'], axis=1)
scaler = MinMaxScaler()

X_activity.meanActivity = scaler.fit_transform(np.expand_dims(X_activity.meanActivity, axis=1))
X_activity.stdActivity = scaler.fit_transform(np.expand_dims(X_activity.stdActivity, axis=1))
X_activity.sumActivity = scaler.fit_transform(np.expand_dims(X_activity.sumActivity, axis=1))
y_activity = finalDF.afftype
#X_activity
# Out:
# /home/ismael/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_activity = X_activity.drop(['gender'], axis=1)
X_activity = X_activity.drop(['age'], axis=1)
X_activity = X_activity.drop(['inpatient'], axis=1)
X_activity = X_activity.drop(['edu'], axis=1)
X_activity = X_activity.drop(['marriage'], axis=1)
X_activity = X_activity.drop(['work'], axis=1)
#X_activity = X_activity.drop(['activity'], axis=1)
X_activity = X_activity.drop(['madrs1'], axis=1)
X_activity = X_activity.drop(['madrs2'], axis=1)

# %%
mejorC = 0
mejorGamma = 0
maxPredictSVM = 0.0
for i in [1, 10, 100, 1000]:
    for j in [0.001]:
        model = SVC(kernel='rbf', C=i, gamma=j)
        scores = cross_val_score(model, X_activity, y_activity, cv=10, scoring='accuracy')
        if scores.mean() > maxPredictSVM:
            maxPredictSVM = scores.mean()
            mejorC = i
            mejorGamma = j
        print('C =', i, 'gamma =', j, ':', scores.mean())
# Out:
# C = 1 gamma = 0.001 : 0.6807546876618668
# C = 10 gamma = 0.001 : 0.6807546876618668
# C = 100 gamma = 0.001 : 0.6807546876618668
# C = 1000 gamma = 0.001 : 0.6807546876618668

# %%
bestNumberOfEstimatorsRFC = 0
maxValueRFC = 0
for i in range(1, 101, 10):
    model = RandomForestClassifier(n_estimators=i)
    scores = cross_val_score(model, X_activity, y_activity, cv=10, scoring='accuracy')
    if scores.mean() > maxValueRFC:
        maxValueRFC = scores.mean()
        bestNumberOfEstimatorsRFC = i
    print('Numero estimadores' , i)
    print(scores.mean())
# Out:
# Numero estimadores 1
# 0.5825080285921476
# Numero estimadores 11
# 0.6211864187299285
# Numero estimadores 21
# 0.6316093442453122
# Numero estimadores 31
# 0.6254778307261992
# Numero estimadores 41
# 0.6247293587485755
# Numero estimadores 51
# 0.6234577333471459
# Numero estimadores 61
# 0.6280560447529265
# Numero estimadores 71
# 0.6247371283538796
# Numero estimadores 81
# 0.6262716254014296
# Numero estimadores 91
# 0.6285610690976897

# %%
bestNumberOfEstimatorsGBC = 0
maxValueGBC = 0.0
for i in range(1, 101, 10):
    model = GradientBoostingClassifier(random_state=1, n_estimators=i)
    scores = cross_val_score(model, X_activity, y_activity, cv=10, scoring='accuracy')
    if scores.mean() > maxValueGBC:
        maxValueGBC = scores.mean()
        bestNumberOfEstimatorsGBC = i
    print('Numero estimadores' , i)
    print(scores.mean())
# Out:
# Numero estimadores 1
# 0.6807546876618668
# Numero estimadores 11
# 0.6807559825960843
# Numero estimadores 21
# 0.6782127317932248
# Numero estimadores 31
# 0.6789754480472391
# Numero estimadores 41
# 0.6789586139024137
# Numero estimadores 51
# 0.674643893090231
# Numero estimadores 61
# 0.6728659484098207
# Numero estimadores 71
# 0.6680332539107013
# Numero estimadores 81
# 0.6665000517973686
# Numero estimadores 91
# 0.6631901999378431

# %%
model = clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                     hidden_layer_sizes=(50, 50), random_state=1)
scores = cross_val_score(model, X_activity, y_activity, cv=10, scoring='accuracy')
print(scores.mean())
# Out:
# 0.6754079042784626

# %%
activity = pd.concat([X_activity, y_activity], axis=1)
prueba1 = []
prueba2 = []
for i in range(0,24):
    aux1 = activity[(activity['hour'] == i) & (activity['afftype'] == 1)]
    aux2 = activity[(activity['hour'] == i) & (activity['afftype'] == 2)]
    prueba1.append(aux1['activity'].mean())
    prueba2.append(aux2['activity'].mean())

# %%
activity = pd.concat([X_activity, y_activity], axis=1)
prueba1 = np.array([], dtype='f')
prueba2 = np.array([], dtype='f')
for i in range(0,24):
    aux1 = activity[(activity['hour'] == i) & (activity['afftype'] == 1)]
    aux2 = activity[(activity['hour'] == i) & (activity['afftype'] == 2)]
    np.concatenate(prueba1, aux1['activity'].mean())
    np.concatenate(prueba2, aux2['activity'].mean())

# %%
for i in range(0,24):
    print(i, prueba1[i] - prueba2[i])

# %%
# Out:
#       activity  hour
# 0     0.159484    12
# 1     0.130960    13
# 2     0.128480    14
# 3     0.100683    15
# 4     0.109782    16
# 5     0.096574    17
# 6     0.059422    18
# 7     0.027829    19
# 8     0.045997    20
# 9     0.019112    21
# 10    0.014934    22
# 11    0.068446    23
# 12    0.003682     0
# 13    0.001878     1
# 14    0.003254     2
# 15    0.001855     3
# 16    0.005624     4
# 17    0.000446     5
# 18    0.004602     6
# 19    0.006305     7
# 20    0.067526     8
# 21    0.051290     9
# 22    0.182080    10
# 23    0.161969    11
# 24    0.113822    12
# 25    0.160165    13
# 26    0.128802    14
# 27    0.034939    15
# 28    0.169433    16
# 29    0.181610    17
# ...        ...   ...
# 8827  0.000000     4
# 8828  0.000000     5
# 8829  0.000000     6
# 8830  0.000000     7
# 8831  0.000000     8
# 8832  0.000253     9
# 8833  0.000000    10
# 8834  0.001887    11
# 8835  0.000152    12
# 8836  0.000000    13
# 8837  0.000000    14
# 8838  0.000000    15
# 8839  0.001772    16
# 8840  0.000000    17
# 8841  0.000000    18
# 8842  0.000129    19
# 8843  0.000000    20
# 8844  0.000115    21
# 8845  0.000078    22
# 8846  0.000000    23
# 8847  0.000000     0
# 8848  0.000000     1
# 8849  0.000000     2
# 8850  0.000000     3
# 8851  0.000000     4
# 8852  0.000000     5
# 8853  0.000000     6
# 8854  0.000000     7
# 8855  0.000000     8
# 8856  0.079045     9
#
# [8857 rows x 2 columns]
